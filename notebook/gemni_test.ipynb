# %%
# !pip install -q -U google-genai

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (24.1.1)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.1
#     Uninstalling pip-24.1.1:
#       Successfully uninstalled pip-24.1.1
# Successfully installed pip-26.0.1

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

# response = client.models.generate_content(
#     model="gemini-3-flash-preview", contents=""
# )

print(type(client.models.list()))
# Out:
# <class 'google.genai.pagers.Pager'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       6 # response = client.models.generate_content(
#       7 #     model="gemini-3-flash-preview", contents=""
#       8 # )
#      10 print(type(client.models.list()))
# ---> 11 print(client.models.list().models)
#
# AttributeError: 'Pager' object has no attribute 'models'

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents={'text': 'Why is the sky blue?'},
    config={
        'temperature': 0,
        'top_p': 0.95,
        'top_k': 20,
    },
)
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""The sky is blue because of a phenomenon called **Rayleigh scattering**. Here's a breakdown:
#
# 1.  **Sunlight is White Light:** The light from the sun appears white to us, but it's actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet). Each color has a different wavelength, with red having the longest wavelength and violet/blue having the shortest.
#
# 2.  **Earth's Atmosphere:** Our atmosphere is composed mainly of tiny gas molecules (like nitrogen and oxygen) and small particles. These molecules are much smaller than the wavelengths of visible light.
#
# 3.  **Scattering:** When sunlight enters the atmosphere, it collides with these tiny gas molecules. This causes the light to be scattered, or redirected, in all directions.
#
# 4.  **Why Blue?** Rayleigh scattering is much more effective at scattering shorter wavelengths of light (blue and violet) than longer wavelengths (red, orange, yellow). In fact, blue light is scattered about 10 times more effectively than red light.
#     *   So, as sunlight travels through the atmosphere, the blue and violet light gets scattered in every direction across the sky.
#     *   When you look up, you see this scattered blue light coming from all parts of the sky, making it appear blue.
#
# 5.  **Why not Violet?** While violet light is scattered even more than blue light, our eyes are more sensitive to blue light. Also, some of the violet light is absorbed higher in the atmosphere, and the sun emits slightly less violet light than blue light.
#
# **What about other colors?**
# The longer wavelengths (red, orange, yellow) are scattered much less. They tend to travel more directly through the atmosphere to our eyes.
#
# **This also explains sunsets and sunrises:**
# When the sun is low on the horizon (sunrise or sunset), its light has to travel through a much greater amount of atmosphere to reach our eyes. By the time it gets to us, most of the blue and violet light has been scattered away, leaving primarily the longer wavelengths like red, orange, and yellow to create those beautiful colors we see."""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='sRnEaezMJf3D4-EPgOCtmQQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=454,
#   prompt_token_count=7,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=7
#     ),
#   ],
#   thoughts_token_count=930,
#   total_token_count=1391
# ) automatic_function_calling_history=[] parsed=None

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", api_key=api_key)

# %%
model.invoke("What is the meaning of life?")
# Out:
# AIMessage(content='That\'s one of the oldest, most profound, and most debated questions in human history! And the most honest answer is: **There isn\'t one single, universally accepted answer.**\n\nThe "meaning of life" is not a scientific fact to be discovered, but rather a philosophical, spiritual, and deeply personal inquiry. Different people, cultures, religions, and philosophies offer various perspectives:\n\n1.  **No Universal, Pre-Determined Meaning (Existentialism/Absurdism):**\n    *   Some philosophies, like existentialism (Sartre, Camus), suggest that life has no inherent, pre-ordained meaning. We are simply "thrown" into existence, and it\'s up to each individual to create their own meaning and purpose.\n    *   The universe itself might be indifferent or "absurd" in its lack of inherent meaning, and our struggle is to find or create meaning in the face of that absurdity.\n\n2.  **Meaning is Divinely Ordained (Religious/Spiritual Views):**\n    *   Many religions provide a clear framework for the meaning of life, often tied to a higher power, a cosmic plan, or spiritual laws.\n    *   **Christianity:** To glorify God, live according to His will, seek salvation, and love one\'s neighbor.\n    *   **Islam:** To submit to Allah, live righteously, and strive for paradise.\n    *   **Buddhism:** To alleviate suffering, achieve enlightenment (Nirvana), and cultivate compassion.\n    *   **Hinduism:** To fulfill one\'s dharma (duty), accumulate good karma, and ultimately achieve moksha (liberation from the cycle of rebirth).\n    *   **Judaism:** To live a life of holiness, obey God\'s commandments, and contribute to the betterment of the world (Tikkun Olam).\n\n3.  **Meaning is Self-Created or Discovered (Humanism/Individualism):**\n    *   Many people find meaning through human-centered values and experiences, without necessarily invoking a divine purpose. This meaning is often found in:\n        *   **Love and Connection:** Deep relationships with family, friends, and community.\n        *   **Contribution and Purpose:** Making a positive impact on the world, helping others, or working towards a cause greater than oneself.\n        *   **Growth and Learning:** Continuous self-improvement, acquiring knowledge, understanding the world.\n        *   **Experience and Beauty:** Appreciating art, nature, travel, adventure, and the richness of human experience.\n        *   **Happiness and Fulfillment:** Seeking joy, contentment, and a sense of well-being (often through "eudaimonia" – a flourishing life, not just fleeting pleasure).\n        *   **Creativity and Expression:** Art, music, writing, innovation, bringing new things into existence.\n\n**In summary:**\n\nThe meaning of life is likely not a fixed destination, but rather an ongoing **journey of inquiry, creation, and discovery**. It\'s something you might define for yourself, based on your values, experiences, beliefs, and the impact you wish to have.\n\nPerhaps the "meaning of life" isn\'t *what* life is, but *how* you choose to live it.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d2607-c180-7542-8986-23392c8441d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 1851, 'total_tokens': 1859, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1164}})
